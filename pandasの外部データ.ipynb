# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ```
# NumPy と　pandasをインポートしておきます
# ```

# %% [markdown]
# # 事前準備
#
# ## データ
#
# - CSV: 201704health.csv
# - HTML: 201704weather.html
#
# ## ライブラリインストール
#
# - HTML解析用 (lxml): `$ pip install lxml`
# - Excel操作用 (openpyxl): `$ pip install openpyxl`

# %% [markdown]
# # CSVファイルの読み込み
#
# - 201704health.csv
#
# ## データ
#
# - 日付
# - 歩数
# - 摂取カロリー

# %%
df = pd.read_csv("201704health.csv")

# %% [markdown]
# ```
# 201704health.csv ファイルを、データフレームに変換します
# ```

# %%
df.head()
# Out:
#            日付     歩数  摂取カロリー
# 0  2017-04-01   5439    2500
# 1  2017-04-02   2510    2300
# 2  2017-04-03  10238    1950
# 3  2017-04-04   8209    1850
# 4  2017-04-05   9434    1930

# %% [markdown]
# ```
# データの先頭を見てみましょう
# ```

# %%
df.tail()
# Out:
#             日付    歩数  摂取カロリー
# 21  2017-04-26  7492    1850
# 22  2017-04-27  7203    1930
# 23  2017-04-28  7302    1850
# 24  2017-04-29  6033    2300
# 25  2017-04-30  4093    1950

# %% [markdown]
# ```
# データの最後を見てみましょう
# ```

# %%
df["歩数"]
# Out:
# 0      5439
# 1      2510
# 2     10238
# 3      8209
# 4      9434
# 5      7593
# 6      9320
# 7      4873
# 8      7493
# 9      7289
# 10     6481
# 11    10287
# 12     8043
# 13     7435
# 14     8031
# 15     8475
# 16     8132
# 17    15328
# 18    12849
# 19     4029
# 20     7823
# 21     7492
# 22     7203
# 23     7302
# 24     6033
# 25     4093
# Name: 歩数, dtype: int64

# %% [markdown]
# ```
# カラム 歩数のデータを確認します。
# ```

# %%
df.mean(axis=0)
# Out:
# 歩数        7747.461538
# 摂取カロリー    2028.846154
# dtype: float64

# %% [markdown]
# ```
# 歩数と摂取カロリーの平均値を出力しました。
# ```

# %%
df['日付'].astype(np.datetime64)
# Out:
# 0    2017-04-01
# 1    2017-04-02
# 2    2017-04-03
# 3    2017-04-04
# 4    2017-04-05
# 5    2017-04-06
# 6    2017-04-07
# 7    2017-04-08
# 8    2017-04-10
# 9    2017-04-11
# 10   2017-04-12
# 11   2017-04-13
# 12   2017-04-14
# 13   2017-04-15
# 14   2017-04-17
# 15   2017-04-18
# 16   2017-04-19
# 17   2017-04-20
# 18   2017-04-21
# 19   2017-04-22
# 20   2017-04-25
# 21   2017-04-26
# 22   2017-04-27
# 23   2017-04-28
# 24   2017-04-29
# 25   2017-04-30
# Name: 日付, dtype: datetime64[ns]

# %% [markdown]
# ```
# CSVファイルからデータフレームにした際に、カラム 日付　は文字列になっています。
# ソートなどに使用できるように、日付型に変換をします。
# ここでは、変換結果を出力しているだけです
# ```

# %%
df['date'] = df['日付'].astype(np.datetime64)

# %% [markdown]
# ```
# 新たなカラム date に カラム 日付 から日付型に変換したデータを入れます
# ```

# %%
df_health = df

# %% [markdown]
# ```
# 新たなデータフレーム df_health にコピーします。
# この後は、 df_health を使用していきます
# ```

# %%
df_health
# Out:
#             日付     歩数  摂取カロリー       date
# 0   2017-04-01   5439    2500 2017-04-01
# 1   2017-04-02   2510    2300 2017-04-02
# 2   2017-04-03  10238    1950 2017-04-03
# 3   2017-04-04   8209    1850 2017-04-04
# 4   2017-04-05   9434    1930 2017-04-05
# 5   2017-04-06   7593    1800 2017-04-06
# 6   2017-04-07   9320    1940 2017-04-07
# 7   2017-04-08   4873    2300 2017-04-08
# 8   2017-04-10   7493    1850 2017-04-10
# 9   2017-04-11   7289    1930 2017-04-11
# 10  2017-04-12   6481    2300 2017-04-12
# 11  2017-04-13  10287    1800 2017-04-13
# 12  2017-04-14   8043    1940 2017-04-14
# 13  2017-04-15   7435    2300 2017-04-15
# 14  2017-04-17   8031    1940 2017-04-17
# 15  2017-04-18   8475    2300 2017-04-18
# 16  2017-04-19   8132    1950 2017-04-19
# 17  2017-04-20  15328    1800 2017-04-20
# 18  2017-04-21  12849    1940 2017-04-21
# 19  2017-04-22   4029    2300 2017-04-22
# 20  2017-04-25   7823    1950 2017-04-25
# 21  2017-04-26   7492    1850 2017-04-26
# 22  2017-04-27   7203    1930 2017-04-27
# 23  2017-04-28   7302    1850 2017-04-28
# 24  2017-04-29   6033    2300 2017-04-29
# 25  2017-04-30   4093    1950 2017-04-30

# %% [markdown]
# ```
# df_healthの内容を確認します
# ```

# %% [markdown]
# # HTML表の読み込み
#
# - 201704weather.html
#
# 以下のサイトから2017年4月の東京の気象データをダウンロード
# http://www.data.jma.go.jp/obd/stats/etrn/view/daily_s1.php?prec_no=44&block_no=47662&year=2017&month=4&day=&view=
#
# - 必要な表を選択
# - 日にちと気温関係のデータのみにする
# - ヘッダーの処理
# - 日にちを、日付として扱えるように変換

# %%
tables = pd.read_html("201704weather.html")

# %% [markdown]
# ```
# pandasには、HTMLのテーブル構造をデータフレームに変換するツールが含まれています。
# read_html関数に、HTMLファイルを渡すと、HTML内にある、複数のテーブルが取り込まれます
# ```

# %%
tables
# Out:
# [     0        1        2      3      4           5        6      7     8   \
#  0     日  気圧(hPa)  降水量(mm)  気温(℃)  湿度(％)  風向・風速(m/s)  日照時間(h)  雪(cm)  天気概況
#  1    現地       海面      NaN    NaN    NaN         NaN      NaN    NaN   NaN
#  2    平均       平均       合計     最大     平均          最高       最低     平均    最小
#  3   1時間     10分間       風速     風向     風速          風向       合計      値   NaN
#  4     1   1010.9   1013.9    5.5    1.5         0.5      6.3    8.9   4.6
#  5     2   1011.0   1014.0     --     --          --      8.7   14.2   4.6
#  6     3   1013.5   1016.4    1.5    1.5         1.0      9.9   16.1   6.4
#  7     4   1021.3   1024.3     --     --          --     11.2   17.3   4.5
#  8     5   1023.3   1026.2     --     --          --     14.7   20.7   7.7
#  9     6   1019.7   1022.6    0.5    0.5         0.5     16.7   21.2  12.9
#  10    7   1012.6   1015.5    3.0    1.5         0.5     17.5   21.6  15.5
#  11    8   1009.5   1012.4    7.0    2.0         1.0     15.3   17.7  12.6
#  12    9   1005.1   1008.0    9.0    3.5         1.5     13.8   15.2  11.1
#  13   10   1017.4   1020.3     --     --          --     10.4   15.7   6.9
#  14   11   1004.5   1007.4   46.0    8.0         1.5      8.5   10.7   6.4
#  15   12    999.3   1002.1    0.0    0.0         0.0     14.3   21.6   8.3
#  16   13   1010.8   1013.7    0.0    0.0         0.0     12.3   17.6   6.7
#  17   14   1013.7   1016.6     --     --          --     15.0   21.5   7.4
#  18   15   1010.4   1013.2    0.0    0.0         0.0     18.6   24.2  14.2
#  19   16   1010.7   1013.6     --     --          --     18.9   26.1  12.0
#  20   17   1009.5   1012.4   13.0    7.5         2.5     18.3   26.1  13.8
#  21   18    989.9    992.7   17.5    8.0         2.0     20.0   25.7  14.1
#  22   19    996.1    998.9     --     --          --     18.0   26.1  12.7
#  23   20   1008.9   1011.8    0.0    0.0         0.0     15.7   21.1  10.9
#  24   21   1005.0   1007.9    0.0    0.0         0.0     15.6   19.2  13.0
#  25   22   1005.1   1008.0   15.0    5.5         3.0     14.3   18.4   9.7
#  26   23   1014.4   1017.3    0.5    0.5         0.5     13.6   20.3   8.8
#  27   24   1023.8   1026.7     --     --          --     14.5   19.6  10.1
#  28   25   1022.7   1025.6     --     --          --     16.0   21.0  12.0
#  29   26   1011.5   1014.3    0.0    0.0         0.0     16.9   19.4  13.9
#  30   27   1002.6   1005.4    3.5    1.5         1.0     14.7   19.4  12.1
#  31   28   1004.1   1006.9     --     --          --     15.9   21.6  11.5
#  32   29   1003.4   1006.2    0.0    0.0         0.0     16.2   23.4  10.2
#  33   30   1006.6   1009.5     --     --          --     17.8   24.3  10.7
#
#        9     ...          11    12    13              14                15  \
#  0    NaN    ...         NaN   NaN   NaN             NaN               NaN
#  1    NaN    ...         NaN   NaN   NaN             NaN               NaN
#  2   平均風速    ...      最大瞬間風速    降雪  最深積雪  昼(06:00-18:00)  夜(18:00-翌日06:00)
#  3    NaN    ...         NaN   NaN   NaN             NaN               NaN
#  4     80    ...         2.7   5.1   北北東             9.4                北東
#  5     59    ...         2.3   6.4    南東             9.6                 南
#  6     63    ...         2.8   8.4    北西            15.8                北西
#  7     63    ...         2.9   6.2   南南東            10.4                 南
#  8     64    ...         3.5   7.7     南            11.3                南東
#  9     68    ...         5.5   9.2   南南西            18.4               南南西
#  10    83    ...         5.6   9.0     南            16.6               南南西
#  11    96    ...         2.0   5.6     南             8.8               南南西
#  12    93    ...         2.2   5.2    北西             9.4                 北
#  13    49    ...         2.9   6.1   南南東             9.9                北西
#  14    90    ...         3.0   7.3    北西            12.5                北西
#  15    58    ...         3.9   7.4   北北西            15.7               北北西
#  16    51    ...         3.0   6.2    北西            11.1               北北西
#  17    51    ...         3.7   8.0     南            12.7                 南
#  18    57    ...         4.8   8.8   南南西            16.6               南南西
#  19    57    ...         2.7   6.3   南南東            10.4               南南東
#  20    65    ...         3.2   7.7    南東            14.7               東南東
#  21    75    ...         4.7  10.1     南            20.9                 南
#  22    50    ...         4.4   9.6    北西            19.8               西北西
#  23    47    ...         3.7   6.6     南            10.9               西北西
#  24    73    ...         1.8   3.8   南南東             5.3               南南東
#  25    74    ...         2.0   4.4   北北東             8.0               北北東
#  26    60    ...         2.9   6.8    南東            11.7               南南東
#  27    61    ...         3.0   6.5   南南東             9.7               南南東
#  28    63    ...         4.7   8.8     南            13.8                 南
#  29    70    ...         4.8   8.7     南            14.8               南南西
#  30    73    ...         3.3   5.9   南南東             9.9               南南東
#  31    58    ...         2.9   5.5   東北東            10.0                北東
#  32    63    ...         2.6   7.5    北西            14.1               西北西
#  33    60    ...         3.2   7.7   南南東            12.9               南南東
#
#        16   17   18             19         20
#  0    NaN  NaN  NaN            NaN        NaN
#  1    NaN  NaN  NaN            NaN        NaN
#  2    NaN  NaN  NaN            NaN        NaN
#  3    NaN  NaN  NaN            NaN        NaN
#  4    0.0   --   --          雨後一時曇       曇時々晴
#  5    8.9   --   --          薄曇時々晴        晴後曇
#  6    7.3   --   --  晴一時曇後一時雨、雷を伴う  晴一時雨、雷を伴う
#  7   12.0   --   --              晴      薄曇時々晴
#  8    9.4   --   --             薄曇      曇後一時晴
#  9    7.2   --   --           曇一時晴       雨一時曇
#  10   2.8   --   --         雨時々曇後晴     晴後曇時々雨
#  11   0.0   --   --       雨時々曇一時霧雨       曇時々雨
#  12   0.0   --   --           雨時々曇      薄曇時々晴
#  13   6.5   --   --             薄曇          曇
#  14   0.0   --   --             大雨   晴時々薄曇一時雨
#  15   9.7   --   --          薄曇時々晴    曇時々雨一時晴
#  16   9.1   --   --          晴後一時曇          晴
#  17  11.7   --   --             快晴     晴後一時薄曇
#  18   8.2   --   --       薄曇時々晴一時雨      晴時々薄曇
#  19  11.9   --   --         晴後時々薄曇      薄曇一時晴
#  20   3.8   --   --          曇後一時雨          雨
#  21   5.1   --   --           曇一時雨        曇後晴
#  22  11.8   --   --              晴         快晴
#  23   9.0   --   --           晴後薄曇          曇
#  24   0.1   --   --              曇       曇一時晴
#  25   0.1   --   --          曇後一時雨        雨後曇
#  26  10.5   --   --              晴       曇時々晴
#  27   7.0   --   --            曇後晴       晴一時曇
#  28   9.5   --   --           晴一時曇         薄曇
#  29   0.0   --   --              曇        曇後雨
#  30   5.0   --   --           曇一時雨          曇
#  31   9.5   --   --           晴一時曇       晴一時曇
#  32  10.4   --   --           晴時々曇  晴一時雨、雷を伴う
#  33  12.3   --   --             快晴         快晴
#
#  [34 rows x 21 columns],          0            1          2           3
#  0  利用される方へ  よくある質問（FAQ）  気象観測統計の解説  年・季節・各月の天候]

# %% [markdown]
# ```
# 取得したものを確認しています
# ```

# %%
len(tables)
# Out:
# 2

# %% [markdown]
# ```
# このHTMLには、2つのテーブルが含まれていました
# ```

# %%
tables[1]
# Out:
#          0            1          2           3
# 0  利用される方へ  よくある質問（FAQ）  気象観測統計の解説  年・季節・各月の天候

# %% [markdown]
# ```
# 2個目のテーブルを見てみます。
# 目的のものではないことがわかります。
# ```

# %%
df = tables[0]

# %% [markdown]
# ```
# 一つ目のテーブルをデータフレームとして、変数dfに入れます
# ```

# %%
df.head()
# Out:
#     0        1        2      3      4           5        6      7     8   \
# 0    日  気圧(hPa)  降水量(mm)  気温(℃)  湿度(％)  風向・風速(m/s)  日照時間(h)  雪(cm)  天気概況
# 1   現地       海面      NaN    NaN    NaN         NaN      NaN    NaN   NaN
# 2   平均       平均       合計     最大     平均          最高       最低     平均    最小
# 3  1時間     10分間       風速     風向     風速          風向       合計      値   NaN
# 4    1   1010.9   1013.9    5.5    1.5         0.5      6.3    8.9   4.6
#
#      9   ...       11   12    13              14                15   16   17  \
# 0   NaN  ...      NaN  NaN   NaN             NaN               NaN  NaN  NaN
# 1   NaN  ...      NaN  NaN   NaN             NaN               NaN  NaN  NaN
# 2  平均風速  ...   最大瞬間風速   降雪  最深積雪  昼(06:00-18:00)  夜(18:00-翌日06:00)  NaN  NaN
# 3   NaN  ...      NaN  NaN   NaN             NaN               NaN  NaN  NaN
# 4    80  ...      2.7  5.1   北北東             9.4                北東  0.0   --
#
#     18     19    20
# 0  NaN    NaN   NaN
# 1  NaN    NaN   NaN
# 2  NaN    NaN   NaN
# 3  NaN    NaN   NaN
# 4   --  雨後一時曇  曇時々晴
#
# [5 rows x 21 columns]

# %% [markdown]
# ```
# 新たに作ったデータフレームの内容を見てみます。
# 4行目まで、ヘッダーが並んでいることがわかります。
# 今回取り込んだテーブルのヘッダーが複雑になっていることから、どのカラムが必要なのかがわかりにくい状況です。
# 元のHTMLを表示させて、今回使用したい、「日」「平均気温」「最高気温」「最低気温」だけを抜き出したいと思います。
# ```

# %%
df_weather = pd.DataFrame(df.iloc[:, [0, 6, 7, 8]])

# %% [markdown]
# ```
# カラムの 0, 6, 7, 8 が順に、「日」「平均気温」「最高気温」「最低気温」となっていましたので、
# 新たなデータフレーム df_weather を、必要なカラムだけにして生成します。
# ```

# %%
df_weather = df_weather.drop([0, 1, 2, 3])

# %% [markdown]
# ```
# ヘッダーが意味とあっていないので、不要なので、一旦削除します
# ```

# %%
df_weather.head()
# Out:
#    0     6     7    8
# 4  1   6.3   8.9  4.6
# 5  2   8.7  14.2  4.6
# 6  3   9.9  16.1  6.4
# 7  4  11.2  17.3  4.5
# 8  5  14.7  20.7  7.7

# %% [markdown]
# ```
# データの先頭を確認します。
# ```

# %%
df_weather = df_weather.rename(columns={0: '日', 6: '平均気温', 7: '最高気温', 8: '最低気温'})

# %% [markdown]
# ```
# カラム名が数字のままでは扱いにくいので、カラム名を変更します
# ```

# %%
df_weather.head()
# Out:
#    日  平均気温  最高気温 最低気温
# 4  1   6.3   8.9  4.6
# 5  2   8.7  14.2  4.6
# 6  3   9.9  16.1  6.4
# 7  4  11.2  17.3  4.5
# 8  5  14.7  20.7  7.7

# %% [markdown]
# ```
# あらためて、データフレームの先頭を確認します
# ```

# %%
df_weather.dtypes
# Out:
# 日       object
# 平均気温    object
# 最高気温    object
# 最低気温    object
# dtype: object

# %% [markdown]
# ```
# 各データが、どのようなタイプかを確認します。
# 数値や日付となっていることを期待していましたが、残念ながらobjectと表示されました。
# これは、HTMLから取り込んだ際に、先頭の4行目までに、文字列が入っていて、数値などに変換できなかったために発生しました。
# このままでは、データ処理で扱えないので、データの型を整えます
# ```

# %%
df_weather[['平均気温', '最高気温', '最低気温']] = df_weather[['平均気温', '最高気温', '最低気温']].astype(np.float)

# %% [markdown]
# ```
# 「平均気温」「最高気温」「最低気温」は、小数点以下を含んでいるので、floatで扱うことにしました。
# データを変換してそのまま同じカラムに代入しています
# ```

# %%
df_weather
# Out:
#      日  平均気温  最高気温  最低気温
# 4    1   6.3   8.9   4.6
# 5    2   8.7  14.2   4.6
# 6    3   9.9  16.1   6.4
# 7    4  11.2  17.3   4.5
# 8    5  14.7  20.7   7.7
# 9    6  16.7  21.2  12.9
# 10   7  17.5  21.6  15.5
# 11   8  15.3  17.7  12.6
# 12   9  13.8  15.2  11.1
# 13  10  10.4  15.7   6.9
# 14  11   8.5  10.7   6.4
# 15  12  14.3  21.6   8.3
# 16  13  12.3  17.6   6.7
# 17  14  15.0  21.5   7.4
# 18  15  18.6  24.2  14.2
# 19  16  18.9  26.1  12.0
# 20  17  18.3  26.1  13.8
# 21  18  20.0  25.7  14.1
# 22  19  18.0  26.1  12.7
# 23  20  15.7  21.1  10.9
# 24  21  15.6  19.2  13.0
# 25  22  14.3  18.4   9.7
# 26  23  13.6  20.3   8.8
# 27  24  14.5  19.6  10.1
# 28  25  16.0  21.0  12.0
# 29  26  16.9  19.4  13.9
# 30  27  14.7  19.4  12.1
# 31  28  15.9  21.6  11.5
# 32  29  16.2  23.4  10.2
# 33  30  17.8  24.3  10.7

# %% [markdown]
# ```
# データの表示された状況には代わりがありません
# ```

# %%
df_weather.dtypes
# Out:
# 日        object
# 平均気温    float64
# 最高気温    float64
# 最低気温    float64
# dtype: object

# %% [markdown]
# ```
# データの型を再確認しています
# 気温関係の3つのカラムは、floatで扱われていることがわかりました
# 残るは、「日」のデータの変換です。日付で扱えるように変換していきましょう。
# ```

# %%
pd.to_datetime("2017-4-{}".format(1))
# Out:
# Timestamp('2017-04-01 00:00:00')

# %% [markdown]
# ```
# 今回のデータには、日の文字列のみが入っています。
# このデータを 2017年4月　として、日付型にする方法を確認します
# ```

# %%
df_weather['日'].apply(lambda x: pd.to_datetime("2017-4-{}".format(x)))
# Out:
# 4    2017-04-01
# 5    2017-04-02
# 6    2017-04-03
# 7    2017-04-04
# 8    2017-04-05
# 9    2017-04-06
# 10   2017-04-07
# 11   2017-04-08
# 12   2017-04-09
# 13   2017-04-10
# 14   2017-04-11
# 15   2017-04-12
# 16   2017-04-13
# 17   2017-04-14
# 18   2017-04-15
# 19   2017-04-16
# 20   2017-04-17
# 21   2017-04-18
# 22   2017-04-19
# 23   2017-04-20
# 24   2017-04-21
# 25   2017-04-22
# 26   2017-04-23
# 27   2017-04-24
# 28   2017-04-25
# 29   2017-04-26
# 30   2017-04-27
# 31   2017-04-28
# 32   2017-04-29
# 33   2017-04-30
# Name: 日, dtype: datetime64[ns]

# %% [markdown]
# ```
# カラム 日 に対して、applyメソッドを使うことで、データ変換した結果を表示しています。
# apply は、データ一つづつに順次関数を適用するものです。
# lambda は Pythonの無名関数です。ここでは、引数を x とし、先程実行した日付型を返すpandasの関数 to_datetime を実行しています。
# ```

# %%
df_weather['date'] = df_weather['日'].apply(lambda x: pd.to_datetime("2017-4-{}".format(x)))

# %% [markdown]
# ```
# 上記で実行した カラム 日から、日付型を返す実行結果を、新たなカラム dateに代入しています。
# ```

# %%
df_weather.head()
# Out:
#    日  平均気温  最高気温  最低気温       date
# 4  1   6.3   8.9   4.6 2017-04-01
# 5  2   8.7  14.2   4.6 2017-04-02
# 6  3   9.9  16.1   6.4 2017-04-03
# 7  4  11.2  17.3   4.5 2017-04-04
# 8  5  14.7  20.7   7.7 2017-04-05

# %% [markdown]
# ```
# データの先頭を確認します
# ```

# %%
df_weather
# Out:
#      日  平均気温  最高気温  最低気温       date
# 4    1   6.3   8.9   4.6 2017-04-01
# 5    2   8.7  14.2   4.6 2017-04-02
# 6    3   9.9  16.1   6.4 2017-04-03
# 7    4  11.2  17.3   4.5 2017-04-04
# 8    5  14.7  20.7   7.7 2017-04-05
# 9    6  16.7  21.2  12.9 2017-04-06
# 10   7  17.5  21.6  15.5 2017-04-07
# 11   8  15.3  17.7  12.6 2017-04-08
# 12   9  13.8  15.2  11.1 2017-04-09
# 13  10  10.4  15.7   6.9 2017-04-10
# 14  11   8.5  10.7   6.4 2017-04-11
# 15  12  14.3  21.6   8.3 2017-04-12
# 16  13  12.3  17.6   6.7 2017-04-13
# 17  14  15.0  21.5   7.4 2017-04-14
# 18  15  18.6  24.2  14.2 2017-04-15
# 19  16  18.9  26.1  12.0 2017-04-16
# 20  17  18.3  26.1  13.8 2017-04-17
# 21  18  20.0  25.7  14.1 2017-04-18
# 22  19  18.0  26.1  12.7 2017-04-19
# 23  20  15.7  21.1  10.9 2017-04-20
# 24  21  15.6  19.2  13.0 2017-04-21
# 25  22  14.3  18.4   9.7 2017-04-22
# 26  23  13.6  20.3   8.8 2017-04-23
# 27  24  14.5  19.6  10.1 2017-04-24
# 28  25  16.0  21.0  12.0 2017-04-25
# 29  26  16.9  19.4  13.9 2017-04-26
# 30  27  14.7  19.4  12.1 2017-04-27
# 31  28  15.9  21.6  11.5 2017-04-28
# 32  29  16.2  23.4  10.2 2017-04-29
# 33  30  17.8  24.3  10.7 2017-04-30

# %% [markdown]
# ```
# データ型を変換し、この後使用しやす目的の物が得られました。
# データの型の変換や新たなカラムに代入することをステップを追って確認してきました。
#
# Excelなででは、マウスを使って、メニューから変換を行うことが多いと思います。それに比べると直感的にはわかりにくいかもしれません。
# ただ、データが数千、数万と増えて行った場合、Excelでは処理が仕切れない場合があります。
# また、プログラムであれば、再利用可能となり、多くの作業を行う場合は効率的になります。
# ```

# %% [markdown]
# # データフレームの応用
#
# - 日付データを元に同じ行に列を増やす
# - 上記で使用した、CSVとHTMLデータを元に一つのデータフレームを作る

# %%
df_health.head()
# Out:
#            日付     歩数  摂取カロリー       date
# 0  2017-04-01   5439    2500 2017-04-01
# 1  2017-04-02   2510    2300 2017-04-02
# 2  2017-04-03  10238    1950 2017-04-03
# 3  2017-04-04   8209    1850 2017-04-04
# 4  2017-04-05   9434    1930 2017-04-05

# %% [markdown]
# ```
# CSVから読みんでデータフレームに変換した、 df_health を再確認します。
# ```

# %%
df_weather.head()
# Out:
#    日  平均気温  最高気温  最低気温       date
# 4  1   6.3   8.9   4.6 2017-04-01
# 5  2   8.7  14.2   4.6 2017-04-02
# 6  3   9.9  16.1   6.4 2017-04-03
# 7  4  11.2  17.3   4.5 2017-04-04
# 8  5  14.7  20.7   7.7 2017-04-05

# %% [markdown]
# ```
# HTMLファイルから読み込んで各種データ変換を行った、 df_weather を確認します。
# ```

# %%
df_201704 = pd.merge(df_health, df_weather)

# %% [markdown]
# ```
# 2つのデータフレームを 同じカラム名 date でつなげます。
# ```

# %%
df_201704
# Out:
#             日付     歩数  摂取カロリー       date   日  平均気温  最高気温  最低気温
# 0   2017-04-01   5439    2500 2017-04-01   1   6.3   8.9   4.6
# 1   2017-04-02   2510    2300 2017-04-02   2   8.7  14.2   4.6
# 2   2017-04-03  10238    1950 2017-04-03   3   9.9  16.1   6.4
# 3   2017-04-04   8209    1850 2017-04-04   4  11.2  17.3   4.5
# 4   2017-04-05   9434    1930 2017-04-05   5  14.7  20.7   7.7
# 5   2017-04-06   7593    1800 2017-04-06   6  16.7  21.2  12.9
# 6   2017-04-07   9320    1940 2017-04-07   7  17.5  21.6  15.5
# 7   2017-04-08   4873    2300 2017-04-08   8  15.3  17.7  12.6
# 8   2017-04-10   7493    1850 2017-04-10  10  10.4  15.7   6.9
# 9   2017-04-11   7289    1930 2017-04-11  11   8.5  10.7   6.4
# 10  2017-04-12   6481    2300 2017-04-12  12  14.3  21.6   8.3
# 11  2017-04-13  10287    1800 2017-04-13  13  12.3  17.6   6.7
# 12  2017-04-14   8043    1940 2017-04-14  14  15.0  21.5   7.4
# 13  2017-04-15   7435    2300 2017-04-15  15  18.6  24.2  14.2
# 14  2017-04-17   8031    1940 2017-04-17  17  18.3  26.1  13.8
# 15  2017-04-18   8475    2300 2017-04-18  18  20.0  25.7  14.1
# 16  2017-04-19   8132    1950 2017-04-19  19  18.0  26.1  12.7
# 17  2017-04-20  15328    1800 2017-04-20  20  15.7  21.1  10.9
# 18  2017-04-21  12849    1940 2017-04-21  21  15.6  19.2  13.0
# 19  2017-04-22   4029    2300 2017-04-22  22  14.3  18.4   9.7
# 20  2017-04-25   7823    1950 2017-04-25  25  16.0  21.0  12.0
# 21  2017-04-26   7492    1850 2017-04-26  26  16.9  19.4  13.9
# 22  2017-04-27   7203    1930 2017-04-27  27  14.7  19.4  12.1
# 23  2017-04-28   7302    1850 2017-04-28  28  15.9  21.6  11.5
# 24  2017-04-29   6033    2300 2017-04-29  29  16.2  23.4  10.2
# 25  2017-04-30   4093    1950 2017-04-30  30  17.8  24.3  10.7

# %% [markdown]
# ```
# 2つのデータフレームをつなげた結果を確認します。
# 今回のデータは、df_health は4月の歩数などのデータですが、記録が残っていない日がありました。
# その為、データをつなぎ合わせた時に、df_healthに無い日については、データが欠落しています。
# ```

# %%
df_201704 = pd.merge(df_weather, df_health, how='outer')

# %% [markdown]
# ```
# df_weather から df_health にマージするように変更し、更に、how='outer' オプションを付けることで、df_healthに無い日付についてもデータも取り込んでいます
# ```

# %%
df_201704
# Out:
#      日  平均気温  最高気温  最低気温       date          日付       歩数  摂取カロリー
# 0    1   6.3   8.9   4.6 2017-04-01  2017-04-01   5439.0  2500.0
# 1    2   8.7  14.2   4.6 2017-04-02  2017-04-02   2510.0  2300.0
# 2    3   9.9  16.1   6.4 2017-04-03  2017-04-03  10238.0  1950.0
# 3    4  11.2  17.3   4.5 2017-04-04  2017-04-04   8209.0  1850.0
# 4    5  14.7  20.7   7.7 2017-04-05  2017-04-05   9434.0  1930.0
# 5    6  16.7  21.2  12.9 2017-04-06  2017-04-06   7593.0  1800.0
# 6    7  17.5  21.6  15.5 2017-04-07  2017-04-07   9320.0  1940.0
# 7    8  15.3  17.7  12.6 2017-04-08  2017-04-08   4873.0  2300.0
# 8    9  13.8  15.2  11.1 2017-04-09         NaN      NaN     NaN
# 9   10  10.4  15.7   6.9 2017-04-10  2017-04-10   7493.0  1850.0
# 10  11   8.5  10.7   6.4 2017-04-11  2017-04-11   7289.0  1930.0
# 11  12  14.3  21.6   8.3 2017-04-12  2017-04-12   6481.0  2300.0
# 12  13  12.3  17.6   6.7 2017-04-13  2017-04-13  10287.0  1800.0
# 13  14  15.0  21.5   7.4 2017-04-14  2017-04-14   8043.0  1940.0
# 14  15  18.6  24.2  14.2 2017-04-15  2017-04-15   7435.0  2300.0
# 15  16  18.9  26.1  12.0 2017-04-16         NaN      NaN     NaN
# 16  17  18.3  26.1  13.8 2017-04-17  2017-04-17   8031.0  1940.0
# 17  18  20.0  25.7  14.1 2017-04-18  2017-04-18   8475.0  2300.0
# 18  19  18.0  26.1  12.7 2017-04-19  2017-04-19   8132.0  1950.0
# 19  20  15.7  21.1  10.9 2017-04-20  2017-04-20  15328.0  1800.0
# 20  21  15.6  19.2  13.0 2017-04-21  2017-04-21  12849.0  1940.0
# 21  22  14.3  18.4   9.7 2017-04-22  2017-04-22   4029.0  2300.0
# 22  23  13.6  20.3   8.8 2017-04-23         NaN      NaN     NaN
# 23  24  14.5  19.6  10.1 2017-04-24         NaN      NaN     NaN
# 24  25  16.0  21.0  12.0 2017-04-25  2017-04-25   7823.0  1950.0
# 25  26  16.9  19.4  13.9 2017-04-26  2017-04-26   7492.0  1850.0
# 26  27  14.7  19.4  12.1 2017-04-27  2017-04-27   7203.0  1930.0
# 27  28  15.9  21.6  11.5 2017-04-28  2017-04-28   7302.0  1850.0
# 28  29  16.2  23.4  10.2 2017-04-29  2017-04-29   6033.0  2300.0
# 29  30  17.8  24.3  10.7 2017-04-30  2017-04-30   4093.0  1950.0

# %% [markdown]
# ```
# 4月分のデータが手に入りました。
# ```

# %%
df_2017_fix = pd.DataFrame(df_201704.sort_values(by='date'), columns=['date', '歩数', '摂取カロリー', '平均気温', '最高気温', '最低気温'], )

# %% [markdown]
# ```
# 不要なカラムもあるので、改めて、データフレーム df_2017_fix を生成します。
# この時、必要なカラムだけを残し、念のためカラム date でソートしています。
# ```

# %%
df_2017_fix
# Out:
#          date       歩数  摂取カロリー  平均気温  最高気温  最低気温
# 0  2017-04-01   5439.0  2500.0   6.3   8.9   4.6
# 1  2017-04-02   2510.0  2300.0   8.7  14.2   4.6
# 2  2017-04-03  10238.0  1950.0   9.9  16.1   6.4
# 3  2017-04-04   8209.0  1850.0  11.2  17.3   4.5
# 4  2017-04-05   9434.0  1930.0  14.7  20.7   7.7
# 5  2017-04-06   7593.0  1800.0  16.7  21.2  12.9
# 6  2017-04-07   9320.0  1940.0  17.5  21.6  15.5
# 7  2017-04-08   4873.0  2300.0  15.3  17.7  12.6
# 8  2017-04-09      NaN     NaN  13.8  15.2  11.1
# 9  2017-04-10   7493.0  1850.0  10.4  15.7   6.9
# 10 2017-04-11   7289.0  1930.0   8.5  10.7   6.4
# 11 2017-04-12   6481.0  2300.0  14.3  21.6   8.3
# 12 2017-04-13  10287.0  1800.0  12.3  17.6   6.7
# 13 2017-04-14   8043.0  1940.0  15.0  21.5   7.4
# 14 2017-04-15   7435.0  2300.0  18.6  24.2  14.2
# 15 2017-04-16      NaN     NaN  18.9  26.1  12.0
# 16 2017-04-17   8031.0  1940.0  18.3  26.1  13.8
# 17 2017-04-18   8475.0  2300.0  20.0  25.7  14.1
# 18 2017-04-19   8132.0  1950.0  18.0  26.1  12.7
# 19 2017-04-20  15328.0  1800.0  15.7  21.1  10.9
# 20 2017-04-21  12849.0  1940.0  15.6  19.2  13.0
# 21 2017-04-22   4029.0  2300.0  14.3  18.4   9.7
# 22 2017-04-23      NaN     NaN  13.6  20.3   8.8
# 23 2017-04-24      NaN     NaN  14.5  19.6  10.1
# 24 2017-04-25   7823.0  1950.0  16.0  21.0  12.0
# 25 2017-04-26   7492.0  1850.0  16.9  19.4  13.9
# 26 2017-04-27   7203.0  1930.0  14.7  19.4  12.1
# 27 2017-04-28   7302.0  1850.0  15.9  21.6  11.5
# 28 2017-04-29   6033.0  2300.0  16.2  23.4  10.2
# 29 2017-04-30   4093.0  1950.0  17.8  24.3  10.7

# %% [markdown]
# ```
# データを確認します。
# ```

# %%
df_2017_fill = df_2017_fix.fillna(0)

# %% [markdown]
# ```
# 歩数、摂取カロリーの欠損値を、0とします
# ```

# %%
df_2017_fill
# Out:
#          date       歩数  摂取カロリー  平均気温  最高気温  最低気温
# 0  2017-04-01   5439.0  2500.0   6.3   8.9   4.6
# 1  2017-04-02   2510.0  2300.0   8.7  14.2   4.6
# 2  2017-04-03  10238.0  1950.0   9.9  16.1   6.4
# 3  2017-04-04   8209.0  1850.0  11.2  17.3   4.5
# 4  2017-04-05   9434.0  1930.0  14.7  20.7   7.7
# 5  2017-04-06   7593.0  1800.0  16.7  21.2  12.9
# 6  2017-04-07   9320.0  1940.0  17.5  21.6  15.5
# 7  2017-04-08   4873.0  2300.0  15.3  17.7  12.6
# 8  2017-04-09      0.0     0.0  13.8  15.2  11.1
# 9  2017-04-10   7493.0  1850.0  10.4  15.7   6.9
# 10 2017-04-11   7289.0  1930.0   8.5  10.7   6.4
# 11 2017-04-12   6481.0  2300.0  14.3  21.6   8.3
# 12 2017-04-13  10287.0  1800.0  12.3  17.6   6.7
# 13 2017-04-14   8043.0  1940.0  15.0  21.5   7.4
# 14 2017-04-15   7435.0  2300.0  18.6  24.2  14.2
# 15 2017-04-16      0.0     0.0  18.9  26.1  12.0
# 16 2017-04-17   8031.0  1940.0  18.3  26.1  13.8
# 17 2017-04-18   8475.0  2300.0  20.0  25.7  14.1
# 18 2017-04-19   8132.0  1950.0  18.0  26.1  12.7
# 19 2017-04-20  15328.0  1800.0  15.7  21.1  10.9
# 20 2017-04-21  12849.0  1940.0  15.6  19.2  13.0
# 21 2017-04-22   4029.0  2300.0  14.3  18.4   9.7
# 22 2017-04-23      0.0     0.0  13.6  20.3   8.8
# 23 2017-04-24      0.0     0.0  14.5  19.6  10.1
# 24 2017-04-25   7823.0  1950.0  16.0  21.0  12.0
# 25 2017-04-26   7492.0  1850.0  16.9  19.4  13.9
# 26 2017-04-27   7203.0  1930.0  14.7  19.4  12.1
# 27 2017-04-28   7302.0  1850.0  15.9  21.6  11.5
# 28 2017-04-29   6033.0  2300.0  16.2  23.4  10.2
# 29 2017-04-30   4093.0  1950.0  17.8  24.3  10.7

# %% [markdown]
# ```
# 最終的に出来上がったデータを確認します。
# ```

# %% [markdown]
# # ExcelやCSVにデータを保存

# %%
df_2017_fill.to_excel('運動量と天気201704.xlsx')

# %% [markdown]
# ```
# 生成したデータフレームは、このNotebookを閉じてしまうとデータを失います。
# ここでは、Excelでデータフレームを保存しています。
# ```

# %%
df_2017_fill.to_csv('運動量と天気201704.csv')

# %% [markdown]
# ```
# CSVにも保存します。
# これらの保存したデータを、デスクトップアプリで確認をしてみてください。
# ```

# %% [markdown]
# # Pickle形式でデータフレームを保存

# %%
df_2017_fill.to_pickle("./df_2017.db")

# %% [markdown]
# ```
# ExcelやCSVにデータの保存が出来ることがわかりました。
# 改めてロードして、場合によっては、データの加工・型の変更などが必要になる場合があります。
#
# データフレームをそのままのPythonのオブジェクトとして保存する方法があります。
# PickleというPython標準のデータシリアライズ化を用いた方法で、生成したデータフレームを保存しておきます。
#
# df_2017.db というファイルができていることを確認してください。
# 次の章では、このデータを元に、可視化などを行っていきます。
# ```

# %% [markdown]
# # SQLite に保存
# RDBMSの一つである、SQLiteのテーブルにデータを保存する方法を実行します。
#
# O/Rマッパーである、SQLAlchemyを使用しますので、インストールを行います。
# $ pip install sqlalchemy

# %%
from sqlalchemy import create_engine

# %% [markdown]
# ```
# 必要なモジュールをインポート
# ```

# %%
engine = create_engine('sqlite:///mydata.sqlite')

# %% [markdown]
# ```
# データベースコネクションを生成
# ここでは、mydata.sqlite というファイルにデータベースのデータが出来上がります
# ```

# %%
df_2017_fill.to_sql('data', engine)

# %% [markdown]
# ```
# dataテーブルに、データフレームの行列を保存しています。
# ```
